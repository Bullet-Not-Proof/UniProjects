# %%
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.metrics import explained_variance_score
from sklearn.metrics import *
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Load "diabetes" datasets from SKlearn and do the PCA for n=3, and plot the data.

# %%
diabetes = datasets.load_diabetes()
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
#df['target'] = pd.Series(diabetes.target)

dataNorm = df.copy()
mu = dataNorm.iloc[:,2:].mean(axis=0) # mean of each col
sigma = dataNorm.iloc[:,2:].std(axis=0)  # std dev of each col
dataNorm.iloc[:,2:]=(dataNorm.iloc[:,2:]-mu)/sigma

pca = PCA(n_components=3)
Xnorm = dataNorm.iloc[:,2:].copy().values
pca.fit(Xnorm)
pcaData = pca.transform(Xnorm)

x = pcaData[:,0]
y = pcaData[:,1]
z = pcaData[:,2]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(x, y, z, s=2)
#print(pca)
#var = pca.explained_variance_ratio_

#var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)
#plt.plot(var1)
#plt.xlabel("Principal components")
#plt.ylabel("Variance captured")

# %% [markdown]
# What is the variance (%) covered by first 3 components?  How is this percentage of variance computed?

# %%
## i don't know how to calculate this

print(np.var(dataNorm.iloc[:,0:3]))
# Out:
# age    0.002262
# sex    0.002262
# bmi    0.997738
# dtype: float64

# %% [markdown]
# ##### Is there any correlation between these three components?

# %%
print(dataNorm['age'].corr(dataNorm['sex']))
print(dataNorm['sex'].corr(dataNorm['bmi']))
print(dataNorm['age'].corr(dataNorm['bmi']))

## there is no correlation above 0.20 with any of these features
# Out:
# 0.17373710056366062
# 0.08816139902276235
# 0.1850846661465556

# %%
# Out:
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.1.3
#     Uninstalling matplotlib-3.1.3:
#       Successfully uninstalled matplotlib-3.1.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\users\\tom.s\\anaconda3\\lib\\site-packages\\~atplotlib\\backends\\_backend_agg.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
