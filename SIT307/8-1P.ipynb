# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Load "digits" datasets from SKlearn. Classify digit classes using KNN. Use the same data splitting and performance metrics that you have used in previous week (week 7). Report your findings including comparison of results with week 7.

# %%
digits = datasets.load_digits()
df = pd.DataFrame(digits['data'])
df.fillna(value=df.mean(axis=0), axis=0, inplace=True)

scaler = MinMaxScaler()
dataNorm = scaler.fit_transform(df.to_numpy())

xTrain, xTest, yTrain, yTest = train_test_split(pcaData, digits['target'], test_size=.2, random_state=0)
KNN = KNeighborsClassifier()
KNN.fit(xTrain, yTrain)

plot_decision_regions(xTest, yTest, clf=KNN, legend=1)
plt.title('KNN')
plt.legend(ncol=1)
plt.axis("off")
plt.show()

print("Training accuracy of KNN : {}".format(metrics.accuracy_score(yTrain, KNN.predict(xTrain))))
print("Testing accuracy of KNN : {}".format(metrics.accuracy_score(yTest, KNN.predict(xTest))))

svcRbf = SVC(gamma=.01, C=1)
svcRbf.fit(xTrain, yTrain)

plot_decision_regions(xTest, yTest, clf=svcRbf, legend=1)
plt.title('SVM')
plt.legend(ncol=1)
plt.axis("off")
plt.show()

print("Training accuracy of SVM: {}".format(metrics.accuracy_score(yTrain, svcRbf.predict(xTrain))))
print("Testing accuracy of SVM : {}".format(metrics.accuracy_score(yTest, svcRbf.predict(xTest))))
# Out:
# C:\Users\Tom.S\anaconda3\lib\site-packages\mlxtend\plotting\decision_regions.py:352: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   **scatter_kwargs
# Training accuracy of KNN : 0.7404314544189283
# Testing accuracy of KNN : 0.6194444444444445
# C:\Users\Tom.S\anaconda3\lib\site-packages\mlxtend\plotting\decision_regions.py:352: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   **scatter_kwargs
# Training accuracy of SVM: 0.5963813500347948
# Testing accuracy of SVM : 0.5805555555555556

# %% [markdown]
# Create digits classification model using DT algorithm using 50-50% and 70-30% data splitting methods. Compare performances of these two models and explain impact of difference in data splitting on the performances of the model.

# %%
xTrain, xTest, yTrain, yTest = train_test_split(pcaData, digits['target'], test_size=.5, random_state=0)
DTC = DecisionTreeClassifier(random_state=0)
DTC.fit(xTrain, yTrain)
print(cross_val_score(DTC, xTrain, yTrain))

plot_decision_regions(xTest, yTest, clf=DTC, legend=1)
plt.title('DTC 50/50')
plt.legend(ncol=1)
plt.axis("off")
plt.show()

print("Training accuracy of DTC 50/50 : {}".format(metrics.accuracy_score(yTrain, svcRbf.predict(xTrain))))
print("Testing accuracy of DTC 50/50 : {}".format(metrics.accuracy_score(yTest, svcRbf.predict(xTest))))



xTrain, xTest, yTrain, yTest = train_test_split(pcaData, digits['target'], test_size=.3, random_state=0)
DTC = DecisionTreeClassifier(random_state=0)
DTC.fit(xTrain, yTrain)
print(cross_val_score(DTC, xTrain, yTrain))

plot_decision_regions(xTest, yTest, clf=DTC, legend=1)
plt.title('DTC 70/30')
plt.legend(ncol=1)
plt.axis("off")
plt.show()

print("Training accuracy of DTC 70/30 : {}".format(metrics.accuracy_score(yTrain, svcRbf.predict(xTrain))))
print("Testing accuracy of DTC 70/30 : {}".format(metrics.accuracy_score(yTest, svcRbf.predict(xTest))))
# Out:
# [0.62222222 0.56666667 0.53333333 0.55865922 0.56424581]
# C:\Users\Tom.S\anaconda3\lib\site-packages\mlxtend\plotting\decision_regions.py:352: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   **scatter_kwargs
# Training accuracy of DTC 50/50 : 0.60913140311804
# Testing accuracy of DTC 50/50 : 0.5773081201334817
# C:\Users\Tom.S\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Unknown label type: 'continuous-multioutput'
#
#   FitFailedWarning)
# C:\Users\Tom.S\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...
